# %%
from transformers import TimeSeriesTransformerConfig, TimeSeriesTransformerModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/requests/compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import TimeSeriesTransformerConfig, TimeSeriesTransformerModel
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/dependency_versions_check.py:17
#      14 import sys
#      16 from .dependency_versions_table import deps
# ---> 17 from .utils.versions import require_version, require_version_core
#      20 # define which module versions we always want to check at run time
#      21 # (usually the ones defined in `install_requires` in setup.py)
#      22 #
#      23 # order specific notes:
#      24 # - tqdm must be checked before tokenizers
#      26 pkgs_to_check_at_runtime = "python tqdm regex requests packaging filelock numpy tokenizers".split()
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/__init__.py:34
#      25 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      26 from .doc import (
#      27     add_code_sample_docstrings,
#      28     add_end_docstrings,
#    (...)
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#      37     ModelOutput,
#      38     PaddingStrategy,
#      39     TensorType,
#      40     cached_property,
#      41     can_return_loss,
#      42     expand_dims,
#      43     find_labels,
#      44     flatten_dict,
#      45     is_jax_tensor,
#      46     is_numpy_array,
#      47     is_tensor,
#      48     is_tf_tensor,
#      49     is_torch_device,
#      50     is_torch_dtype,
#      51     is_torch_tensor,
#      52     reshape,
#      53     squeeze,
#      54     tensor_size,
#      55     to_numpy,
#      56     to_py_obj,
#      57     transpose,
#      58     working_or_temp_dir,
#      59 )
#      60 from .hub import (
#      61     CLOUDFRONT_DISTRIB_PREFIX,
#      62     DISABLE_TELEMETRY,
#    (...)
#      88     send_example_telemetry,
#      89 )
#      90 from .import_utils import (
#      91     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      92     ENV_VARS_TRUE_VALUES,
#    (...)
#     169     torch_version,
#     170 )
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/generic.py:29
#      25 from typing import Any, ContextManager, List, Tuple
#      27 import numpy as np
# ---> 29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_tf_available():
#      33     import tensorflow as tf
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/import_utils.py:34
#      30 from packaging import version
#      32 from transformers.utils.versions import importlib_metadata
# ---> 34 from . import logging
#      37 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#      39 ENV_VARS_TRUE_VALUES = {"1", "ON", "YES", "TRUE"}
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/logging.py:33
#      29 from typing import Optional
#      31 from tqdm import auto as tqdm_lib
# ---> 33 import huggingface_hub.utils as hf_hub_utils
#      36 _lock = threading.Lock()
#      37 _default_handler: Optional[logging.Handler] = None
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/huggingface_hub/utils/__init__.py:32
#      30 from ._chunk_utils import chunk_iterable
#      31 from ._datetime import parse_datetime
# ---> 32 from ._errors import (
#      33     BadRequestError,
#      34     EntryNotFoundError,
#      35     GatedRepoError,
#      36     HfHubHTTPError,
#      37     LocalEntryNotFoundError,
#      38     RepositoryNotFoundError,
#      39     RevisionNotFoundError,
#      40     hf_raise_for_status,
#      41 )
#      42 from ._fixes import SoftTemporaryDirectory, yaml_dump
#      43 from ._git_credential import (
#      44     erase_from_credential_store,
#      45     list_credential_helpers,
#    (...)
#      49     write_to_credential_store,
#      50 )
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/huggingface_hub/utils/_errors.py:3
#       1 from typing import Optional
# ----> 3 from requests import HTTPError, Response
#       5 from ._deprecation import _deprecate_method
#       6 from ._fixes import JSONDecodeError
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/requests/__init__.py:45
#      41 import warnings
#      43 import urllib3
# ---> 45 from .exceptions import RequestsDependencyWarning
#      47 try:
#      48     from charset_normalizer import __version__ as charset_normalizer_version
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/requests/exceptions.py:9
#       1 """
#       2 requests.exceptions
#       3 ~~~~~~~~~~~~~~~~~~~
#       4
#       5 This module contains the set of Requests' exceptions.
#       6 """
#       7 from urllib3.exceptions import HTTPError as BaseHTTPError
# ----> 9 from .compat import JSONDecodeError as CompatJSONDecodeError
#      12 class RequestException(IOError):
#      13     """There was an ambiguous exception that occurred while handling your
#      14     request.
#      15     """
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/requests/compat.py:13
#      11     import chardet
#      12 except ImportError:
# ---> 13     import charset_normalizer as chardet
#      15 import sys
#      17 # -------
#      18 # Pythons
#      19 # -------
#      20
#      21 # Syntax sugar.
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/charset_normalizer/__init__.py:23
#       1 """
#       2 Charset-Normalizer
#       3 ~~~~~~~~~~~~~~
#    (...)
#      21 :license: MIT, see LICENSE for more details.
#      22 """
# ---> 23 from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#      24 from charset_normalizer.legacy import detect
#      25 from charset_normalizer.version import __version__, VERSION
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/charset_normalizer/api.py:10
#       7     PathLike = Union[str, 'os.PathLike[str]']  # type: ignore
#       9 from charset_normalizer.constant import TOO_SMALL_SEQUENCE, TOO_BIG_SEQUENCE, IANA_SUPPORTED
# ---> 10 from charset_normalizer.md import mess_ratio
#      11 from charset_normalizer.models import CharsetMatches, CharsetMatch
#      12 from warnings import warn
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/charset_normalizer/md.py:5
#       2 from typing import Optional, List
#       4 from charset_normalizer.constant import UNICODE_SECONDARY_RANGE_KEYWORD
# ----> 5 from charset_normalizer.utils import is_punctuation, is_symbol, unicode_range, is_accentuated, is_latin, \
#       6     remove_accent, is_separator, is_cjk, is_case_variable, is_hangul, is_katakana, is_hiragana, is_ascii, is_thai
#       9 class MessDetectorPlugin:
#      10     """
#      11     Base abstract class used for mess detection plugins.
#      12     All detectors MUST extend and implement given methods.
#      13     """
#
# ImportError: cannot import name 'COMMON_SAFE_ASCII_CHARACTERS' from 'charset_normalizer.constant' (/Users/maciejkrajewskistudia/.conda/envs/FinDL/lib/python3.8/site-packages/charset_normalizer/constant.py)

# %%
configuration = TimeSeriesTransformerConfig()
model = TimeSeriesTransformerModel(configuration)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 configuration = TimeSeriesTransformerConfig()
# ----> 2 model = TimeSeriesTransformerModel(configuration)
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/dummy_pt_objects.py:5779, in TimeSeriesTransformerModel.__init__(self, *args, **kwargs)
#    5778 def __init__(self, *args, **kwargs):
# -> 5779     requires_backends(self, ["torch"])
#
# File ~/.conda/envs/FinDL/lib/python3.8/site-packages/transformers/utils/import_utils.py:1038, in requires_backends(obj, backends)
#    1036 failed = [msg.format(name) for available, msg in checks if not available()]
#    1037 if failed:
# -> 1038     raise ImportError("".join(failed))
#
# ImportError:
# TimeSeriesTransformerModel requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.
